# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Peer Review Week 4

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Data Science Languages
# Python, R, SQL, Scala, Java, C++, Julia

# %% [markdown]
# ### Data Science Libraries
# Scientific Computing Libraries, Visualization Libraries, Machine Learning Libraries, Deep Learning Libraries

# %% [markdown]
# #### Data Science Tools
# |Cloud|Open Source|Commercial|
# |-|-|-|
# |GoogleCloud, Watson Studio|MySQL, CouchDB, cassandra, Spark|Oracle, tableau, Informatica|

# %% [markdown]
# #### Aritmetics Expression Example
# ###### Below is an example of evaluating aritmetic expression in Python.
# 1 + 2 * 3
# = 7

# %%
#This is a simple arithmetic expression to multiply then add integers.
1 + 2 * 3
# Out:
# 7

# %%
#This will convert 180 minutes to hours by dividing by 60.
inutes = 180
print("%02d hours:%02d minutes" % (divmod(minutes, 60)))
# Out:
# 03 hours:00 minutes

# %% [markdown]
# ### Objectives

# %% [markdown]
# ### Oriconoel Erfe
